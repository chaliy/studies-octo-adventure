# %%
# %matplotlib inline
from numpy import *
from sympy import *
from utils import *

# %%
x1, x2 = symbols('x1 x2')
plot(
    solve(Eq(x1 + 2 * x2, 8), x1)[0], # x1 + 2*x2 <= 8
    solve(Eq(x1 + 2 * x2, 10), x1)[0], # x1 + 2*x2 <= 10
    5.5, # x1 <= 5.5
    Eq(x2, 2.5), # x2 <= 2.5
    (x2, -2, 10)
)

# Eq(x2, 2.5)
# solve(Eq(x1 + 2 * x2, 10), x1)
