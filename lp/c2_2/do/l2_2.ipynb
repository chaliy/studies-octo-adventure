# %% [markdown]
# ### Розв'язок

# %%
from utils import *

# %%
display_code("l2_2.py")
# Out:
# <style type='text/css'>.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><h3>File: l2_2.py</h3><div class="well highlight"><pre><span class="kn">from</span> <span class="nn">collections</span> <span class="kn">import</span> <span class="n">deque</span>
# <span class="kn">import</span> <span class="nn">math</span>
# <span class="kn">from</span> <span class="nn">utils</span> <span class="kn">import</span> <span class="o">*</span>
#
# <span class="k">class</span> <span class="nc">Container</span><span class="p">(</span><span class="nb">object</span><span class="p">):</span>
#
# 	<span class="k">def</span> <span class="nf">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">c</span><span class="p">):</span>
# 		<span class="bp">self</span><span class="o">.</span><span class="n">_weights</span> <span class="o">=</span> <span class="p">[]</span>
# 		<span class="bp">self</span><span class="o">.</span><span class="n">_indexes</span> <span class="o">=</span> <span class="p">[]</span>
# 		<span class="bp">self</span><span class="o">.</span><span class="n">_c</span> <span class="o">=</span> <span class="n">c</span>
#
# 	<span class="k">def</span> <span class="nf">add</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">index</span><span class="p">,</span> <span class="n">weight</span><span class="p">):</span>
# 		<span class="k">if</span> <span class="p">(</span><span class="ow">not</span> <span class="bp">self</span><span class="o">.</span><span class="n">can_fit</span><span class="p">(</span><span class="n">weight</span><span class="p">)):</span>
# 			<span class="k">raise</span> <span class="s">&quot;There is no anough space in container&quot;</span>
# 		<span class="bp">self</span><span class="o">.</span><span class="n">_weights</span><span class="o">.</span><span class="n">append</span><span class="p">(</span><span class="n">weight</span><span class="p">)</span>
# 		<span class="bp">self</span><span class="o">.</span><span class="n">_indexes</span><span class="o">.</span><span class="n">append</span><span class="p">(</span><span class="n">index</span><span class="p">)</span>
#
# 	<span class="k">def</span> <span class="nf">add_if_can_fit</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">index</span><span class="p">,</span> <span class="n">weight</span><span class="p">):</span>
# 		<span class="k">if</span> <span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">can_fit</span><span class="p">(</span><span class="n">weight</span><span class="p">)):</span>
# 			<span class="bp">self</span><span class="o">.</span><span class="n">add</span><span class="p">(</span><span class="n">index</span><span class="p">,</span> <span class="n">weight</span><span class="p">)</span>
# 			<span class="k">return</span> <span class="bp">True</span>
# 		<span class="k">return</span> <span class="bp">False</span>
#
# 	<span class="k">def</span> <span class="nf">filled</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
# 		<span class="k">return</span> <span class="nb">sum</span><span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">_weights</span><span class="p">)</span>
#
# 	<span class="k">def</span> <span class="nf">can_fit</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">weight</span><span class="p">):</span>
# 		<span class="k">return</span> <span class="bp">self</span><span class="o">.</span><span class="n">filled</span><span class="p">()</span> <span class="o">+</span> <span class="n">weight</span> <span class="o">&lt;=</span> <span class="bp">self</span><span class="o">.</span><span class="n">_c</span>
#
# 	<span class="k">def</span> <span class="nf">weights</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
# 		<span class="k">return</span> <span class="bp">self</span><span class="o">.</span><span class="n">_weights</span>
#
# 	<span class="k">def</span> <span class="nf">indexes</span><span class="p">(<

# %% [markdown]
# ### Результат

# %%
# %matplotlib inline
from pylab import *
from l2_2 import *

# %%
s1 = [47, 24, 82, 35, 32, 4, 54, 43, 98, 86, 40, 78, 59, 62, 62, 83, 41, 48, 23, 24]
s2 = [72, 22, 54, 35, 21, 57, 65, 47, 71, 76, 69, 18, 1, 3, 53, 33, 7, 59, 28, 6]
s3 = [97, 20, 84, 8, 34, 98, 91, 76, 98, 15, 52, 71, 89, 59, 6, 10, 16, 24, 9, 39]
s = s1 + s2 + s3
c = 100

# %%
(s1_nfa_containers, s1_nfa_o) = nfa(c, s1)
s1_nfa_containers
# Out:
# [[47, 24],
#  [82],
#  [35, 32, 4],
#  [54, 43],
#  [98],
#  [86],
#  [40],
#  [78],
#  [59],
#  [62],
#  [62],
#  [83],
#  [41, 48],
#  [23, 24]]

# %%
(s1_ffa_containers, s1_ffa_o) = ffa(c, s1)
s1_ffa_containers
# Out:
# [[47, 24, 23],
#  [82],
#  [35, 32, 4, 24],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78],
#  [62],
#  [62],
#  [83],
#  [41, 48]]

# %%
(s1_wfa_containers, s1_wfa_o) = wfa(c, s1)
s1_wfa_containers
# Out:
# [[47, 24],
#  [82],
#  [35, 32, 4],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78],
#  [62, 23],
#  [62, 24],
#  [83],
#  [41, 48]]

# %%
(s1_bfa_containers, s1_bfa_o) = bfa(c, s1)
s1_bfa_containers
# Out:
# [[47, 24, 24],
#  [82],
#  [35, 32, 4, 23],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78],
#  [62],
#  [62],
#  [83],
#  [41, 48]]

# %%
(s1_nfa_sorted_containers, s1_nfa_sorted_o) = nfa_sorted(c, s1)
s1_nfa_sorted_containers
# Out:
# [[98],
#  [86],
#  [83],
#  [82],
#  [78],
#  [62],
#  [62],
#  [59],
#  [54],
#  [48, 47],
#  [43, 41],
#  [40, 35],
#  [32, 24, 24],
#  [23, 4]]

# %%
(s1_ffa_sorted_containers, s1_ffa_sorted_o) = ffa_sorted(c, s1)
s1_ffa_sorted_containers
# Out:
# [[98],
#  [86],
#  [83],
#  [82],
#  [78],
#  [62, 32],
#  [62, 24],
#  [59, 41],
#  [54, 43],
#  [48, 47],
#  [40, 35, 24],
#  [23, 4]]

# %%
(s1_wfa_sorted_containers, s1_wfa_sorted_o) = wfa_sorted(c, s1)
s1_wfa_sorted_containers
# Out:
# [[98],
#  [86],
#  [83],
#  [82],
#  [78],
#  [62, 32],
#  [62, 24],
#  [59, 41],
#  [54, 43],
#  [48, 47],
#  [40, 35, 24],
#  [23, 4]]

# %%
(s1_bfa_sorted_containers, s1_bfa_sorted_o) = bfa_sorted(c, s1)
s1_bfa_sorted_containers
# Out:
# [[98],
#  [86],
#  [83],
#  [82],
#  [78],
#  [62, 24],
#  [62, 32],
#  [59, 41],
#  [54, 43],
#  [48, 47],
#  [40, 35, 24],
#  [23, 4]]

# %%
(s2_nfa_containers, s2_nfa_o) = nfa(c, s2)
s2_nfa_containers
# Out:
# [[72, 22],
#  [54, 35],
#  [21, 57],
#  [65],
#  [47],
#  [71],
#  [76],
#  [69, 18, 1, 3],
#  [53, 33, 7],
#  [59, 28, 6]]

# %%
(s2_ffa_containers, s2_ffa_o) = ffa(c, s2)
s2_ffa_containers
# Out:
# [[72, 22],
#  [54, 35],
#  [21, 57],
#  [65, 33],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6]]

# %%
(s2_wfa_containers, s2_wfa_o) = wfa(c, s2)
s2_wfa_containers
# Out:
# [[72, 22],
#  [54, 35],
#  [21, 57],
#  [65, 33],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6]]

# %%
(s2_bfa_containers, s2_bfa_o) = bfa(c, s2)
s2_bfa_containers
# Out:
# [[72, 22],
#  [54, 35],
#  [21, 57],
#  [65, 33],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6]]

# %%
(s2_nfa_sorted_containers, s2_nfa_sorted_o) = nfa_sorted(c, s2)
s2_nfa_sorted_containers
# Out:
# [[76],
#  [72],
#  [71],
#  [69],
#  [65],
#  [59],
#  [57],
#  [54],
#  [53, 47],
#  [35, 33, 28],
#  [22, 21, 18, 7, 6, 3, 1]]

# %%
(s2_ffa_sorted_containers, s2_ffa_sorted_o) = ffa_sorted(c, s2)
s2_ffa_sorted_containers
# Out:
# [[76, 22, 1],
#  [72, 28],
#  [71, 21, 7],
#  [69, 18, 6, 3],
#  [65, 35],
#  [59, 33],
#  [57],
#  [54],
#  [53, 47]]

# %%
(s2_wfa_sorted_containers, s2_wfa_sorted_o) = wfa_sorted(c, s2)
s2_wfa_sorted_containers
# Out:
# [[76, 6, 1],
#  [72, 7, 3],
#  [71, 18],
#  [69, 21],
#  [65, 22],
#  [59, 28],
#  [57, 33],
#  [54, 35],
#  [53, 47]]

# %%
(s2_bfa_sorted_containers, s2_bfa_sorted_o) = bfa_sorted(c, s2)
s2_bfa_sorted_containers
# Out:
# [[76, 22],
#  [72, 28],
#  [71, 21, 6],
#  [69, 18, 3],
#  [65, 35],
#  [59, 33, 7, 1],
#  [57],
#  [54],
#  [53, 47]]

# %%
(s3_nfa_containers, s3_nfa_o) = nfa(c, s3)
s3_nfa_containers
# Out:
# [[97],
#  [20],
#  [84, 8],
#  [34],
#  [98],
#  [91],
#  [76],
#  [98],
#  [15, 52],
#  [71],
#  [89],
#  [59, 6, 10, 16],
#  [24, 9, 39]]

# %%
(s3_ffa_containers, s3_ffa_o) = ffa(c, s3)
s3_ffa_containers
# Out:
# [[97],
#  [20, 34, 15, 24],
#  [84, 8],
#  [98],
#  [91],
#  [76],
#  [98],
#  [52, 39],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s3_wfa_containers, s3_wfa_o) = wfa(c, s3)
s3_wfa_containers
# Out:
# [[97],
#  [20, 34, 15],
#  [84, 8],
#  [98],
#  [91],
#  [76],
#  [98],
#  [52, 24],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9],
#  [39]]

# %%
(s3_bfa_containers, s3_bfa_o) = bfa(c, s3)
s3_bfa_containers
# Out:
# [[97],
#  [20, 34, 39],
#  [84, 8],
#  [98],
#  [91],
#  [76, 15],
#  [98],
#  [52],
#  [71, 24],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s3_nfa_sorted_containers, s3_nfa_sorted_o) = nfa_sorted(c, s3)
s3_nfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [84],
#  [76],
#  [71],
#  [59],
#  [52, 39],
#  [34, 24, 20, 16],
#  [15, 10, 9, 8, 6]]

# %%
(s3_ffa_sorted_containers, s3_ffa_sorted_o) = ffa_sorted(c, s3)
s3_ffa_sorted_containers
# Out:
# [[98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [84, 16],
#  [76, 24],
#  [71, 20],
#  [59, 34],
#  [52, 39],
#  [15, 10, 9, 8, 6]]

# %%
(s3_wfa_sorted_containers, s3_wfa_sorted_o) = wfa_sorted(c, s3)
s3_wfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [84, 16],
#  [76, 20],
#  [71, 24],
#  [59, 34],
#  [52, 39],
#  [15, 10, 9, 8, 6]]

# %%
(s3_bfa_sorted_containers, s3_bfa_sorted_o) = bfa_sorted(c, s3)
s3_bfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [84, 16],
#  [76, 24],
#  [71, 20],
#  [59, 34],
#  [52, 39],
#  [15, 10, 9, 8, 6]]

# %%
(s_nfa_containers, s_nfa_o) = nfa(c, s)
s_nfa_containers
# Out:
# [[47, 24],
#  [82],
#  [35, 32, 4],
#  [54, 43],
#  [98],
#  [86],
#  [40],
#  [78],
#  [59],
#  [62],
#  [62],
#  [83],
#  [41, 48],
#  [23, 24],
#  [72, 22],
#  [54, 35],
#  [21, 57],
#  [65],
#  [47],
#  [71],
#  [76],
#  [69, 18, 1, 3],
#  [53, 33, 7],
#  [59, 28, 6],
#  [97],
#  [20],
#  [84, 8],
#  [34],
#  [98],
#  [91],
#  [76],
#  [98],
#  [15, 52],
#  [71],
#  [89],
#  [59, 6, 10, 16],
#  [24, 9, 39]]

# %%
(s_ffa_containers, s_ffa_o) = ffa(c, s)
s_ffa_containers
# Out:
# [[47, 24, 23],
#  [82, 15],
#  [35, 32, 4, 24],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78, 21],
#  [62, 33],
#  [62, 20],
#  [83],
#  [41, 48],
#  [72, 22],
#  [54, 35],
#  [57, 34],
#  [65, 24],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6],
#  [97],
#  [84, 8],
#  [98],
#  [91],
#  [76],
#  [98],
#  [52, 39],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s_wfa_containers, s_wfa_o) = wfa(c, s)
s_wfa_containers
# Out:
# [[47, 24, 21],
#  [82],
#  [35, 32, 4],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78],
#  [62, 23],
#  [62, 24],
#  [83],
#  [41, 48],
#  [72, 22],
#  [54, 35],
#  [57, 33],
#  [65, 20],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6],
#  [97],
#  [84, 8],
#  [34, 15, 24],
#  [98],
#  [91],
#  [76],
#  [98],
#  [52, 39],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s_bfa_containers, s_bfa_o) = bfa(c, s)
s_bfa_containers
# Out:
# [[47, 24, 24],
#  [82],
#  [35, 32, 4, 23],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78, 21],
#  [62],
#  [62, 34],
#  [83, 15],
#  [41, 48],
#  [72, 22],
#  [54, 35],
#  [57, 39],
#  [65, 33],
#  [47, 53],
#  [71],
#  [76, 20],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6],
#  [97],
#  [84, 8],
#  [98],
#  [91],
#  [76, 24],
#  [98],
#  [52],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s_nfa_sorted_containers, s_nfa_sorted_o) = nfa_sorted(c, s)
s_nfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [86],
#  [84],
#  [83],
#  [82],
#  [78],
#  [76],
#  [76],
#  [72],
#  [71],
#  [71],
#  [69],
#  [65],
#  [62],
#  [62],
#  [59],
#  [59],
#  [59],
#  [57],
#  [54],
#  [54],
#  [53],
#  [52, 48],
#  [47, 47],
#  [43, 41],
#  [40, 39],
#  [35, 35],
#  [34, 33, 32],
#  [28, 24, 24, 24],
#  [23, 22, 21, 20],
#  [18, 16, 15, 10, 9, 8, 7, 6, 6, 4],
#  [3, 1]]

# %%
(s_ffa_sorted_containers, s_ffa_sorted_o) = ffa_sorted(c, s)
s_ffa_sorted_containers
# Out:
# [[98, 1],
#  [98],
#  [98],
#  [97, 3],
#  [91, 9],
#  [89, 8],
#  [86, 7, 6],
#  [84, 16],
#  [83, 15],
#  [82, 18],
#  [78, 22],
#  [76, 24],
#  [76, 24],
#  [72, 28],
#  [71, 24, 4],
#  [71, 23, 6],
#  [69, 21],
#  [65, 35],
#  [62, 35],
#  [62, 34],
#  [59, 41],
#  [59, 40],
#  [59, 39],
#  [57, 33],
#  [54, 32],
#  [54, 20],
#  [53, 47],
#  [52, 48],
#  [47, 43, 10]]

# %%
(s_wfa_sorted_containers, s_wfa_sorted_o) = wfa_sorted(c, s)
s_wfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [98],
#  [97],
#  [91, 7],
#  [89, 8],
#  [86, 9],
#  [84, 15],
#  [83, 16],
#  [82, 18],
#  [78, 20],
#  [76, 22],
#  [76, 21],
#  [72, 23],
#  [71, 24],
#  [71, 24],
#  [69, 24, 6],
#  [65, 28, 6],
#  [62, 33],
#  [62, 32, 3],
#  [59, 35, 1],
#  [59, 35],
#  [59, 34, 4],
#  [57, 39],
#  [54, 41],
#  [54, 40],
#  [53, 47],
#  [52, 48],
#  [47, 43, 10]]

# %%
(s_bfa_sorted_containers, s_bfa_sorted_o) = bfa_sorted(c, s)
s_bfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [98],
#  [97],
#  [91, 9],
#  [89, 6],
#  [86],
#  [84, 16],
#  [83, 15],
#  [82, 18],
#  [78, 22],
#  [76, 24],
#  [76, 24],
#  [72, 28],
#  [71, 23, 6],
#  [71, 24],
#  [69, 21, 7],
#  [65, 35],
#  [62, 34, 4],
#  [62, 35, 3],
#  [59, 39],
#  [59, 40, 1],
#  [59, 41],
#  [57, 33, 8],
#  [54, 20],
#  [54, 32],
#  [53, 47],
#  [52, 48],
#  [47, 43, 10]]

# %%
display_table(["", "Analitical Minimum"],
	[
		["1", min_analitical(c, s1)],
		["2", min_analitical(c, s2)],
		["3", min_analitical(c, s3)],
		["1+2+3", min_analitical(c, s)]
	])
# Out:
# <table class='table table-striped'><tr><th></th><th>Analitical Minimum</th><tr><tr><td>1</td><td>10.25</td></tr><tr><td>2</td><td>7.97</td></tr><tr><td>3</td><td>9.96</td></tr><tr><td>1+2+3</td><td>28.18</td></tr></table>

# %%
display_table(["", "NFA(#C)", "FFA(#C)", "WFA(#C)", "BFA(#C)", "NFA(O)", "FFA(O)", "WFA(O)", "BFA(O)"],
	[
		["1", len(s1_nfa_containers), len(s1_ffa_containers), len(s1_wfa_containers), len(s1_bfa_containers), s1_nfa_o, s1_ffa_o, s1_wfa_o, s1_bfa_o],
		["2", len(s2_nfa_containers), len(s2_ffa_containers), len(s2_wfa_containers), len(s2_bfa_containers), s2_nfa_o, s2_ffa_o, s2_wfa_o, s2_bfa_o],
		["3", len(s3_nfa_containers), len(s3_ffa_containers), len(s3_wfa_containers), len(s3_bfa_containers), s3_nfa_o, s3_ffa_o, s3_wfa_o, s3_bfa_o],
		["1+2+3", len(s_nfa_containers), len(s_ffa_containers), len(s_wfa_containers), len(s_bfa_containers), s_nfa_o, s_ffa_o, s_wfa_o, s_bfa_o]
	])
# Out:
# <table class='table table-striped'><tr><th></th><th>NFA(#C)</th><th>FFA(#C)</th><th>WFA(#C)</th><th>BFA(#C)</th><th>NFA(O)</th><th>FFA(O)</th><th>WFA(O)</th><th>BFA(O)</th><tr><tr><td>1</td><td>14</td><td>12</td><td>12</td><td>12</td><td>20</td><td>97</td><td>156.55156268712972</td><td>235.55156268712972</td></tr><tr><td>2</td><td>10</td><td>9</td><td>9</td><td>9</td><td>20</td><td>65</td><td>96.76348598610494</td><td>138.76348598610494</td></tr><tr><td>3</td><td>13</td><td>11</td><td>12</td><td>11</td><td>20</td><td>89</td><td>143.9447255563957</td><td>212.94472555639567</td></tr><tr><td>1+2+3</td><td>37</td><td>31</td><td>32</td><td>31</td><td>60</td><td>641</td><td>904.1267190404272</td><td>1509.7283610110712</td></tr></table>

# %%
display_table(["", "NFA(#C)", "FFA(#C)", "WFA(#C)", "BFA(#C)", "NFA(O)", "FFA(O)", "WFA(O)", "BFA(O)"],
	[
		["1", len(s1_nfa_sorted_containers), len(s1_ffa_sorted_containers), len(s1_wfa_sorted_containers), len(s1_bfa_sorted_containers), s1_nfa_sorted_o, s1_ffa_sorted_o, s1_wfa_sorted_o, s1_bfa_sorted_o],
		["2", len(s2_nfa_sorted_containers), len(s2_ffa_sorted_containers), len(s2_wfa_sorted_containers), len(s2_bfa_sorted_containers), s2_nfa_sorted_o, s2_ffa_sorted_o, s2_wfa_sorted_o, s2_bfa_sorted_o],
		["3", len(s3_nfa_sorted_containers), len(s3_ffa_sorted_containers), len(s3_wfa_sorted_containers), len(s3_bfa_sorted_containers), s3_nfa_sorted_o, s3_ffa_sorted_o, s3_wfa_sorted_o, s3_bfa_sorted_o],
		["1+2+3", len(s_nfa_sorted_containers), len(s_ffa_sorted_containers), len(s_wfa_sorted_containers), len(s_bfa_sorted_containers), s_nfa_sorted_o, s_ffa_sorted_o, s_wfa_sorted_o, s_bfa_sorted_o]
	])
# Out:
# <table class='table table-striped'><tr><th></th><th>NFA(#C)</th><th>FFA(#C)</th><th>WFA(#C)</th><th>BFA(#C)</th><th>NFA(O)</th><th>FFA(O)</th><th>WFA(O)</th><th>BFA(O)</th><tr><tr><td>1</td><td>14</td><td>12</td><td>12</td><td>12</td><td>42.99573227355399</td><td>138.99573227355398</td><td>192.89900085101272</td><td>284.89900085101266</td></tr><tr><td>2</td><td>11</td><td>9</td><td>9</td><td>9</td><td>42.99573227355399</td><td>111.99573227355398</td><td>219.5725809496614</td><td>295.57258094966136</td></tr><tr><td>3</td><td>12</td><td>11</td><td>11</td><td>11</td><td>42.99573227355399</td><td>127.99573227355398</td><td>176.3104852186057</td><td>256.31048521860566</td></tr><tr><td>1+2+3</td><td>37</td><td>29</td><td>29</td><td>29</td><td>124.0943445622221</td><td>941.0943445622221</td><td>1559.2332796192134</td><td>2621.233279619215</td></tr></table>

# %% [markdown]
# ### Висновок
# Ознайомився з методами прийняття рішень в умовах повної інформації на прикладі задачі про упакування в контейнери та дослідив особливості їх використання.
