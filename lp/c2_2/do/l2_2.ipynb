# %%
# %matplotlib inline
from pylab import *
from l2_2 import *
from utils import *

# %%
s1 = [47, 24, 82, 35, 32, 4, 54, 43, 98, 86, 40, 78, 59, 62, 62, 83, 41, 48, 23, 24]
s2 = [72, 22, 54, 35, 21, 57, 65, 47, 71, 76, 69, 18, 1, 3, 53, 33, 7, 59, 28, 6]
s3 = [97, 20, 84, 8, 34, 98, 91, 76, 98, 15, 52, 71, 89, 59, 6, 10, 16, 24, 9, 39]
s = s1 + s2 + s3
c = 100

# %%
(s1_nfa_containers, s1_nfa_o) = nfa(c, s1)
s1_nfa_containers
# Out:
# [[47, 24],
#  [82],
#  [35, 32, 4],
#  [54, 43],
#  [98],
#  [86],
#  [40],
#  [78],
#  [59],
#  [62],
#  [62],
#  [83],
#  [41, 48],
#  [23, 24]]

# %%
(s1_ffa_containers, s1_ffa_o) = ffa(c, s1)
s1_ffa_containers
# Out:
# [[47, 24, 23],
#  [82],
#  [35, 32, 4, 24],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78],
#  [62],
#  [62],
#  [83],
#  [41, 48]]

# %%
(s1_wfa_containers, s1_wfa_o) = wfa(c, s1)
s1_wfa_containers
# Out:
# [[47, 24],
#  [82],
#  [35, 32, 4],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78],
#  [62, 23],
#  [62, 24],
#  [83],
#  [41, 48]]

# %%
(s1_bfa_containers, s1_bfa_o) = bfa(c, s1)
s1_bfa_containers
# Out:
# [[47, 24, 24],
#  [82],
#  [35, 32, 4, 23],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78],
#  [62],
#  [62],
#  [83],
#  [41, 48]]

# %%
(s1_nfa_sorted_containers, s1_nfa_sorted_o) = nfa_sorted(c, s1)
s1_nfa_sorted_containers
# Out:
# [[98],
#  [86],
#  [83],
#  [82],
#  [78],
#  [62],
#  [62],
#  [59],
#  [54],
#  [48, 47],
#  [43, 41],
#  [40, 35],
#  [32, 24, 24],
#  [23, 4]]

# %%
(s1_ffa_sorted_containers, s1_ffa_sorted_o) = ffa_sorted(c, s1)
s1_ffa_sorted_containers
# Out:
# [[98],
#  [86],
#  [83],
#  [82],
#  [78],
#  [62, 32],
#  [62, 24],
#  [59, 41],
#  [54, 43],
#  [48, 47],
#  [40, 35, 24],
#  [23, 4]]

# %%
(s1_wfa_sorted_containers, s1_wfa_sorted_o) = wfa_sorted(c, s1)
s1_wfa_sorted_containers
# Out:
# [[98],
#  [86],
#  [83],
#  [82],
#  [78],
#  [62, 32],
#  [62, 24],
#  [59, 41],
#  [54, 43],
#  [48, 47],
#  [40, 35, 24],
#  [23, 4]]

# %%
(s1_bfa_sorted_containers, s1_bfa_sorted_o) = bfa_sorted(c, s1)
s1_bfa_sorted_containers
# Out:
# [[98],
#  [86],
#  [83],
#  [82],
#  [78],
#  [62, 24],
#  [62, 32],
#  [59, 41],
#  [54, 43],
#  [48, 47],
#  [40, 35, 24],
#  [23, 4]]

# %%
(s2_nfa_containers, s2_nfa_o) = nfa(c, s2)
s2_nfa_containers
# Out:
# [[72, 22],
#  [54, 35],
#  [21, 57],
#  [65],
#  [47],
#  [71],
#  [76],
#  [69, 18, 1, 3],
#  [53, 33, 7],
#  [59, 28, 6]]

# %%
(s2_ffa_containers, s2_ffa_o) = ffa(c, s2)
s2_ffa_containers
# Out:
# [[72, 22],
#  [54, 35],
#  [21, 57],
#  [65, 33],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6]]

# %%
(s2_wfa_containers, s2_wfa_o) = wfa(c, s2)
s2_wfa_containers
# Out:
# [[72, 22],
#  [54, 35],
#  [21, 57],
#  [65, 33],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6]]

# %%
(s2_bfa_containers, s2_bfa_o) = bfa(c, s2)
s2_bfa_containers
# Out:
# [[72, 22],
#  [54, 35],
#  [21, 57],
#  [65, 33],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6]]

# %%
(s2_nfa_sorted_containers, s2_nfa_sorted_o) = nfa_sorted(c, s2)
s2_nfa_sorted_containers
# Out:
# [[76],
#  [72],
#  [71],
#  [69],
#  [65],
#  [59],
#  [57],
#  [54],
#  [53, 47],
#  [35, 33, 28],
#  [22, 21, 18, 7, 6, 3, 1]]

# %%
(s2_ffa_sorted_containers, s2_ffa_sorted_o) = ffa_sorted(c, s2)
s2_ffa_sorted_containers
# Out:
# [[76, 22, 1],
#  [72, 28],
#  [71, 21, 7],
#  [69, 18, 6, 3],
#  [65, 35],
#  [59, 33],
#  [57],
#  [54],
#  [53, 47]]

# %%
(s2_wfa_sorted_containers, s2_wfa_sorted_o) = wfa_sorted(c, s2)
s2_wfa_sorted_containers
# Out:
# [[76, 6, 1],
#  [72, 7, 3],
#  [71, 18],
#  [69, 21],
#  [65, 22],
#  [59, 28],
#  [57, 33],
#  [54, 35],
#  [53, 47]]

# %%
(s2_bfa_sorted_containers, s2_bfa_sorted_o) = bfa_sorted(c, s2)
s2_bfa_sorted_containers
# Out:
# [[76, 22],
#  [72, 28],
#  [71, 21, 6],
#  [69, 18, 3],
#  [65, 35],
#  [59, 33, 7, 1],
#  [57],
#  [54],
#  [53, 47]]

# %%
(s3_nfa_containers, s3_nfa_o) = nfa(c, s3)
s3_nfa_containers
# Out:
# [[97],
#  [20],
#  [84, 8],
#  [34],
#  [98],
#  [91],
#  [76],
#  [98],
#  [15, 52],
#  [71],
#  [89],
#  [59, 6, 10, 16],
#  [24, 9, 39]]

# %%
(s3_ffa_containers, s3_ffa_o) = ffa(c, s3)
s3_ffa_containers
# Out:
# [[97],
#  [20, 34, 15, 24],
#  [84, 8],
#  [98],
#  [91],
#  [76],
#  [98],
#  [52, 39],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s3_wfa_containers, s3_wfa_o) = wfa(c, s3)
s3_wfa_containers
# Out:
# [[97],
#  [20, 34, 15],
#  [84, 8],
#  [98],
#  [91],
#  [76],
#  [98],
#  [52, 24],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9],
#  [39]]

# %%
(s3_bfa_containers, s3_bfa_o) = bfa(c, s3)
s3_bfa_containers
# Out:
# [[97],
#  [20, 34, 39],
#  [84, 8],
#  [98],
#  [91],
#  [76, 15],
#  [98],
#  [52],
#  [71, 24],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s3_nfa_sorted_containers, s3_nfa_sorted_o) = nfa_sorted(c, s3)
s3_nfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [84],
#  [76],
#  [71],
#  [59],
#  [52, 39],
#  [34, 24, 20, 16],
#  [15, 10, 9, 8, 6]]

# %%
(s3_ffa_sorted_containers, s3_ffa_sorted_o) = ffa_sorted(c, s3)
s3_ffa_sorted_containers
# Out:
# [[98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [84, 16],
#  [76, 24],
#  [71, 20],
#  [59, 34],
#  [52, 39],
#  [15, 10, 9, 8, 6]]

# %%
(s3_wfa_sorted_containers, s3_wfa_sorted_o) = wfa_sorted(c, s3)
s3_wfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [84, 16],
#  [76, 20],
#  [71, 24],
#  [59, 34],
#  [52, 39],
#  [15, 10, 9, 8, 6]]

# %%
(s3_bfa_sorted_containers, s3_bfa_sorted_o) = bfa_sorted(c, s3)
s3_bfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [84, 16],
#  [76, 24],
#  [71, 20],
#  [59, 34],
#  [52, 39],
#  [15, 10, 9, 8, 6]]

# %%
(s_nfa_containers, s_nfa_o) = nfa(c, s)
s_nfa_containers
# Out:
# [[47, 24],
#  [82],
#  [35, 32, 4],
#  [54, 43],
#  [98],
#  [86],
#  [40],
#  [78],
#  [59],
#  [62],
#  [62],
#  [83],
#  [41, 48],
#  [23, 24],
#  [72, 22],
#  [54, 35],
#  [21, 57],
#  [65],
#  [47],
#  [71],
#  [76],
#  [69, 18, 1, 3],
#  [53, 33, 7],
#  [59, 28, 6],
#  [97],
#  [20],
#  [84, 8],
#  [34],
#  [98],
#  [91],
#  [76],
#  [98],
#  [15, 52],
#  [71],
#  [89],
#  [59, 6, 10, 16],
#  [24, 9, 39]]

# %%
(s_ffa_containers, s_ffa_o) = ffa(c, s)
s_ffa_containers
# Out:
# [[47, 24, 23],
#  [82, 15],
#  [35, 32, 4, 24],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78, 21],
#  [62, 33],
#  [62, 20],
#  [83],
#  [41, 48],
#  [72, 22],
#  [54, 35],
#  [57, 34],
#  [65, 24],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6],
#  [97],
#  [84, 8],
#  [98],
#  [91],
#  [76],
#  [98],
#  [52, 39],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s_wfa_containers, s_wfa_o) = wfa(c, s)
s_wfa_containers
# Out:
# [[47, 24, 21],
#  [82],
#  [35, 32, 4],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78],
#  [62, 23],
#  [62, 24],
#  [83],
#  [41, 48],
#  [72, 22],
#  [54, 35],
#  [57, 33],
#  [65, 20],
#  [47, 53],
#  [71],
#  [76],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6],
#  [97],
#  [84, 8],
#  [34, 15, 24],
#  [98],
#  [91],
#  [76],
#  [98],
#  [52, 39],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s_bfa_containers, s_bfa_o) = bfa(c, s)
s_bfa_containers
# Out:
# [[47, 24, 24],
#  [82],
#  [35, 32, 4, 23],
#  [54, 43],
#  [98],
#  [86],
#  [40, 59],
#  [78, 21],
#  [62],
#  [62, 34],
#  [83, 15],
#  [41, 48],
#  [72, 22],
#  [54, 35],
#  [57, 39],
#  [65, 33],
#  [47, 53],
#  [71],
#  [76, 20],
#  [69, 18, 1, 3, 7],
#  [59, 28, 6],
#  [97],
#  [84, 8],
#  [98],
#  [91],
#  [76, 24],
#  [98],
#  [52],
#  [71],
#  [89],
#  [59, 6, 10, 16, 9]]

# %%
(s_nfa_sorted_containers, s_nfa_sorted_o) = nfa_sorted(c, s)
s_nfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [98],
#  [97],
#  [91],
#  [89],
#  [86],
#  [84],
#  [83],
#  [82],
#  [78],
#  [76],
#  [76],
#  [72],
#  [71],
#  [71],
#  [69],
#  [65],
#  [62],
#  [62],
#  [59],
#  [59],
#  [59],
#  [57],
#  [54],
#  [54],
#  [53],
#  [52, 48],
#  [47, 47],
#  [43, 41],
#  [40, 39],
#  [35, 35],
#  [34, 33, 32],
#  [28, 24, 24, 24],
#  [23, 22, 21, 20],
#  [18, 16, 15, 10, 9, 8, 7, 6, 6, 4],
#  [3, 1]]

# %%
(s_ffa_sorted_containers, s_ffa_sorted_o) = ffa_sorted(c, s)
s_ffa_sorted_containers
# Out:
# [[98, 1],
#  [98],
#  [98],
#  [97, 3],
#  [91, 9],
#  [89, 8],
#  [86, 7, 6],
#  [84, 16],
#  [83, 15],
#  [82, 18],
#  [78, 22],
#  [76, 24],
#  [76, 24],
#  [72, 28],
#  [71, 24, 4],
#  [71, 23, 6],
#  [69, 21],
#  [65, 35],
#  [62, 35],
#  [62, 34],
#  [59, 41],
#  [59, 40],
#  [59, 39],
#  [57, 33],
#  [54, 32],
#  [54, 20],
#  [53, 47],
#  [52, 48],
#  [47, 43, 10]]

# %%
(s_wfa_sorted_containers, s_wfa_sorted_o) = wfa_sorted(c, s)
s_wfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [98],
#  [97],
#  [91, 7],
#  [89, 8],
#  [86, 9],
#  [84, 15],
#  [83, 16],
#  [82, 18],
#  [78, 20],
#  [76, 22],
#  [76, 21],
#  [72, 23],
#  [71, 24],
#  [71, 24],
#  [69, 24, 6],
#  [65, 28, 6],
#  [62, 33],
#  [62, 32, 3],
#  [59, 35, 1],
#  [59, 35],
#  [59, 34, 4],
#  [57, 39],
#  [54, 41],
#  [54, 40],
#  [53, 47],
#  [52, 48],
#  [47, 43, 10]]

# %%
(s_bfa_sorted_containers, s_bfa_sorted_o) = bfa_sorted(c, s)
s_bfa_sorted_containers
# Out:
# [[98],
#  [98],
#  [98],
#  [97],
#  [91, 9],
#  [89, 6],
#  [86],
#  [84, 16],
#  [83, 15],
#  [82, 18],
#  [78, 22],
#  [76, 24],
#  [76, 24],
#  [72, 28],
#  [71, 23, 6],
#  [71, 24],
#  [69, 21, 7],
#  [65, 35],
#  [62, 34, 4],
#  [62, 35, 3],
#  [59, 39],
#  [59, 40, 1],
#  [59, 41],
#  [57, 33, 8],
#  [54, 20],
#  [54, 32],
#  [53, 47],
#  [52, 48],
#  [47, 43, 10]]

# %%
IPyTable(["", "Analitical Minimum"],
	[
		["1", min_analitical(c, s1)],
		["2", min_analitical(c, s2)],
		["3", min_analitical(c, s3)],
		["1+2+3", min_analitical(c, s)]
	])
# Out:
# <table class='table table-striped'><tr><th></th><th>Analitical Minimum</th><tr><tr><td>1</td><td>10</td></tr><tr><td>2</td><td>7</td></tr><tr><td>3</td><td>9</td></tr><tr><td>1+2+3</td><td>28</td></tr></table>

# %%
IPyTable(["", "NFA(#C)", "FFA(#C)", "WFA(#C)", "BFA(#C)", "NFA(O)", "FFA(O)", "WFA(O)", "BFA(O)"],
	[
		["1", len(s1_nfa_containers), len(s1_ffa_containers), len(s1_wfa_containers), len(s1_bfa_containers), s1_nfa_o, s1_ffa_o, s1_wfa_o, s1_bfa_o],
		["2", len(s2_nfa_containers), len(s2_ffa_containers), len(s2_wfa_containers), len(s2_bfa_containers), s2_nfa_o, s2_ffa_o, s2_wfa_o, s2_bfa_o],
		["3", len(s3_nfa_containers), len(s3_ffa_containers), len(s3_wfa_containers), len(s3_bfa_containers), s3_nfa_o, s3_ffa_o, s3_wfa_o, s3_bfa_o],
		["1+2+3", len(s_nfa_containers), len(s_ffa_containers), len(s_wfa_containers), len(s_bfa_containers), s_nfa_o, s_ffa_o, s_wfa_o, s_bfa_o]
	])
# Out:
# <table class='table table-striped'><tr><th></th><th>NFA(#C)</th><th>FFA(#C)</th><th>WFA(#C)</th><th>BFA(#C)</th><th>NFA(O)</th><th>FFA(O)</th><th>WFA(O)</th><th>BFA(O)</th><tr><tr><td>1</td><td>14</td><td>12</td><td>12</td><td>12</td><td>20</td><td>97</td><td>156.551562687</td><td>235.551562687</td></tr><tr><td>2</td><td>10</td><td>9</td><td>9</td><td>9</td><td>20</td><td>65</td><td>96.7634859861</td><td>138.763485986</td></tr><tr><td>3</td><td>13</td><td>11</td><td>12</td><td>11</td><td>20</td><td>89</td><td>143.944725556</td><td>212.944725556</td></tr><tr><td>1+2+3</td><td>37</td><td>31</td><td>32</td><td>31</td><td>60</td><td>641</td><td>904.12671904</td><td>1509.72836101</td></tr></table>

# %%
IPyTable(["", "NFA(#C)", "FFA(#C)", "WFA(#C)", "BFA(#C)", "NFA(O)", "FFA(O)", "WFA(O)", "BFA(O)"],
	[
		["1", len(s1_nfa_sorted_containers), len(s1_ffa_sorted_containers), len(s1_wfa_sorted_containers), len(s1_bfa_sorted_containers), s1_nfa_sorted_o, s1_ffa_sorted_o, s1_wfa_sorted_o, s1_bfa_sorted_o],
		["2", len(s2_nfa_sorted_containers), len(s2_ffa_sorted_containers), len(s2_wfa_sorted_containers), len(s2_bfa_sorted_containers), s2_nfa_sorted_o, s2_ffa_sorted_o, s2_wfa_sorted_o, s2_bfa_sorted_o],
		["3", len(s3_nfa_sorted_containers), len(s3_ffa_sorted_containers), len(s3_wfa_sorted_containers), len(s3_bfa_sorted_containers), s3_nfa_sorted_o, s3_ffa_sorted_o, s3_wfa_sorted_o, s3_bfa_sorted_o],
		["1+2+3", len(s_nfa_sorted_containers), len(s_ffa_sorted_containers), len(s_wfa_sorted_containers), len(s_bfa_sorted_containers), s_nfa_sorted_o, s_ffa_sorted_o, s_wfa_sorted_o, s_bfa_sorted_o]
	])
# Out:
# <table class='table table-striped'><tr><th></th><th>NFA(#C)</th><th>FFA(#C)</th><th>WFA(#C)</th><th>BFA(#C)</th><th>NFA(O)</th><th>FFA(O)</th><th>WFA(O)</th><th>BFA(O)</th><tr><tr><td>1</td><td>14</td><td>12</td><td>12</td><td>12</td><td>42.9957322736</td><td>138.995732274</td><td>192.899000851</td><td>284.899000851</td></tr><tr><td>2</td><td>11</td><td>9</td><td>9</td><td>9</td><td>42.9957322736</td><td>111.995732274</td><td>219.57258095</td><td>295.57258095</td></tr><tr><td>3</td><td>12</td><td>11</td><td>11</td><td>11</td><td>42.9957322736</td><td>127.995732274</td><td>176.310485219</td><td>256.310485219</td></tr><tr><td>1+2+3</td><td>37</td><td>29</td><td>29</td><td>29</td><td>124.094344562</td><td>941.094344562</td><td>1559.23327962</td><td>2621.23327962</td></tr></table>
