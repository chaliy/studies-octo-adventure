# %%
# %matplotlib inline
from pylab import *
from numpy import *
from IPython.display import display
from utils import *
#from l1 import *

# %%
N = [11, 121, 901]
A = [random.rand(n) for n in N]

# %%
# Оцінити похибку обмеження при обчисленні функції розкладом у ряд

# %%
# Оцінити похибку заокруглення
Sd = [sum(a) for a in A] # Сумма подвійної точності
Ss = [sum(float32(a)) for a in A] # Сумма одинарної точності
Ssa = [sum(float32(sorted(a))) for a in A] # Сумма сорованих
Ssd = [sum(float32(sorted(a, reverse=True))) for a in A] # Сумма сорованих спадаючи

Ead = abs(subtract(Sd, Ss))
Easa = abs(subtract(Sd, Ssa))
Easd = abs(subtract(Sd, Ssd))

Vad = abs(divide(Sd, Ss))
Vasa = abs(divide(Sd, Ssa))
Vasd = abs(divide(Sd, Ssd))

# Print results

display_table(["", "N1", "N2", "N3"],[
    ["Подвійна до одинарної(АП)"] + list(Ead),
    ["До сортованної(АП)"] + list(Easa),
    ["До обратно сортованної(АП)"] + list(Easd),
    ["Подвійна до одинарної(ВП)"] + list(Vad),
    ["До сортованної(ВП)"] + list(Vasa),
    ["До обратно сортованної(ВП)"] + list(Vasd)
])

figure(1)
title("Absolute error")
plot(N, Ead)
plot(N, Easa)
plot(N, Easd)
figure(2)
title(u"Relative error")
plot(N, Vad)
plot(N, Vasa)
plot(N, Vasd)
# Out:
# <table class='table table-striped'><tr><th></th><th>N1</th><th>N2</th><th>N3</th><tr><tr><td>Подвійна до одинарної(АП)</td><td>7.44351656756e-07</td><td>2.65914238184e-06</td><td>4.46573057502e-05</td></tr><tr><td>До сортованної(АП)</td><td>2.0932265965e-07</td><td>2.65914238184e-06</td><td>0.000105692462</td></tr><tr><td>До обратно сортованної(АП)</td><td>2.67514498553e-07</td><td>4.97025214941e-06</td><td>0.000319315508875</td></tr><tr><td>Подвійна до одинарної(ВП)</td><td>1.00000014656</td><td>0.999999959635</td><td>0.999999897598</td></tr><tr><td>До сортованної(ВП)</td><td>0.999999958786</td><td>0.999999959635</td><td>0.99999975764</td></tr><tr><td>До обратно сортованної(ВП)</td><td>1.00000005267</td><td>1.00000007545</td><td>0.999999267788</td></tr></table>

# %%
# Дослідити поширення похибок
